# %%
var = 0
while(var != 101):
  var = int(input())
  if var %3 == 0 and var %5 == 0:
    print("FizzBuzz")
  elif var %3 == 0:
    print("Fizz")
  elif var %5 == 0:
    print("Buzz")
  else:
    print(var)
# Out:
# 3
# Fizz
# 6
# Fizz
# 10
# Buzz
# 15
# FizzBuzz
# 17
# 17
# 101
# 101
