# %%
var = 0
while(var != 101):
  var = int(input())
  if var %3 == 0 and var %5 == 0:
    print("FizzBuzz")
  else:
    if var %3 == 0:
      print("Fizz")
    else:
      if var %5 == 0:
        print("Buzz")
      else:
        print(var)
# Out:
# 101
# 101
