# %%
def compute_value(price, tax):
  return price * tax

tax = 1.1
product = int(input())
totall_price = compute_value(product, tax)
print(f"購入金額は{totall_price}円です。")
# Out:
# 1000
# 購入金額は1100.0円です。
